# %% [markdown]
# # EDA recommendation and hypothesis results

# %%
import datetime
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

# %% [markdown]
# # Reading master data

# %%
master_data=pd.read_csv("datasets/master_data.csv")
master_data
# Out:
#         Unnamed: 0  Transaction ID  Date of Travel     Company           City  \
# 0                0        10000011           42377    Pink Cab     ATLANTA GA
# 1                1        10351127           43302  Yellow Cab     ATLANTA GA
# 2                2        10412921           43427  Yellow Cab     ATLANTA GA
# 3                3        10000012           42375    Pink Cab     ATLANTA GA
# 4                4        10320494           43211  Yellow Cab     ATLANTA GA
# ...            ...             ...             ...         ...            ...
# 359387      359387        10307228           43162  Yellow Cab  WASHINGTON DC
# 359388      359388        10319775           43203  Yellow Cab  WASHINGTON DC
# 359389      359389        10347676           43287  Yellow Cab  WASHINGTON DC
# 359390      359390        10358624           43314  Yellow Cab  WASHINGTON DC
# 359391      359391        10370709           43342  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip  Customer ID Payment_Mode  \
# 0           0.644357      -0.191317      0.173709        29290         Card
# 1           0.296133       0.638741      0.197683        29290         Cash
# 2           1.633444       1.343424      1.969777        29290         Card
# 3           0.494768      -0.236620      0.308012        27703         Card
# 4           1.129091       1.084840      1.145168        27703         Card
# ...              ...            ...           ...          ...          ...
# 359387      1.294211       0.894701      1.513492        51406         Cash
# 359388     -1.552887      -1.296907     -1.529409        51406         Cash
# 359389      0.072975      -0.333384      0.326810        51406         Card
# 359390      0.411390      -0.237676      0.494513        51406         Cash
# 359391      0.954162       0.108123      0.893234        51406         Card
#
#        Population      Users  Gender  Age  Income (USD/Month)
# 0        814,885     24,701     Male   28               10813
# 1        814,885     24,701     Male   28               10813
# 2        814,885     24,701     Male   28               10813
# 3        814,885     24,701     Male   27                9237
# 4        814,885     24,701     Male   27                9237
# ...           ...        ...     ...  ...                 ...
# 359387   418,859    127,001   Female   29                6829
# 359388   418,859    127,001   Female   29                6829
# 359389   418,859    127,001   Female   29                6829
# 359390   418,859    127,001   Female   29                6829
# 359391   418,859    127,001   Female   29                6829
#
# [359392 rows x 15 columns]

# %% [markdown]
# # Master Data basic information

# %%
master_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 15 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Unnamed: 0          359392 non-null  int64
#  1   Transaction ID      359392 non-null  int64
#  2   Date of Travel      359392 non-null  int64
#  3   Company             359392 non-null  object
#  4   City                359392 non-null  object
#  5   KM Travelled        359392 non-null  float64
#  6   Price Charged       359392 non-null  float64
#  7   Cost of Trip        359392 non-null  float64
#  8   Customer ID         359392 non-null  int64
#  9   Payment_Mode        359392 non-null  object
#  10  Population          359392 non-null  object
#  11  Users               359392 non-null  object
#  12  Gender              359392 non-null  object
#  13  Age                 359392 non-null  int64
#  14  Income (USD/Month)  359392 non-null  int64
# dtypes: float64(3), int64(6), object(6)
# memory usage: 41.1+ MB

# %% [markdown]
# # Rename master data columns name

# %%
for col in master_data.columns:
    if ' ' in col:
        master_data = master_data.rename(columns={col:col.replace(' ','_')})

# %% [markdown]
# # Define date format function for monthly analysis

# %%
from datetime import datetime, timedelta

def to_date_format(n):
    date_str =(datetime(1899,12,30) + timedelta(n-1)).strftime("%d-%m-%Y")
    date_date =  datetime.strptime(date_str, "%d-%m-%Y")
    return date_date

# %% [markdown]
# # Master data date of travel change formating

# %%
master_data['Date_of_Travel'] = master_data['Date_of_Travel'].apply(lambda x:to_date_format(x))

master_data
# Out:
#         Unnamed:_0  Transaction_ID Date_of_Travel     Company           City  \
# 0                0        10000011     2016-01-07    Pink Cab     ATLANTA GA
# 1                1        10351127     2018-07-20  Yellow Cab     ATLANTA GA
# 2                2        10412921     2018-11-22  Yellow Cab     ATLANTA GA
# 3                3        10000012     2016-01-05    Pink Cab     ATLANTA GA
# 4                4        10320494     2018-04-20  Yellow Cab     ATLANTA GA
# ...            ...             ...            ...         ...            ...
# 359387      359387        10307228     2018-03-02  Yellow Cab  WASHINGTON DC
# 359388      359388        10319775     2018-04-12  Yellow Cab  WASHINGTON DC
# 359389      359389        10347676     2018-07-05  Yellow Cab  WASHINGTON DC
# 359390      359390        10358624     2018-08-01  Yellow Cab  WASHINGTON DC
# 359391      359391        10370709     2018-08-29  Yellow Cab  WASHINGTON DC
#
#         KM_Travelled  Price_Charged  Cost_of_Trip  Customer_ID Payment_Mode  \
# 0           0.644357      -0.191317      0.173709        29290         Card
# 1           0.296133       0.638741      0.197683        29290         Cash
# 2           1.633444       1.343424      1.969777        29290         Card
# 3           0.494768      -0.236620      0.308012        27703         Card
# 4           1.129091       1.084840      1.145168        27703         Card
# ...              ...            ...           ...          ...          ...
# 359387      1.294211       0.894701      1.513492        51406         Cash
# 359388     -1.552887      -1.296907     -1.529409        51406         Cash
# 359389      0.072975      -0.333384      0.326810        51406         Card
# 359390      0.411390      -0.237676      0.494513        51406         Cash
# 359391      0.954162       0.108123      0.893234        51406         Card
#
#        Population      Users  Gender  Age  Income_(USD/Month)
# 0        814,885     24,701     Male   28               10813
# 1        814,885     24,701     Male   28               10813
# 2        814,885     24,701     Male   28               10813
# 3        814,885     24,701     Male   27                9237
# 4        814,885     24,701     Male   27                9237
# ...           ...        ...     ...  ...                 ...
# 359387   418,859    127,001   Female   29                6829
# 359388   418,859    127,001   Female   29                6829
# 359389   418,859    127,001   Female   29                6829
# 359390   418,859    127,001   Female   29                6829
# 359391   418,859    127,001   Female   29                6829
#
# [359392 rows x 15 columns]

# %% [markdown]
# # Split the master data company column pink cab, yellow cab

# %%
PinkCab = master_data[master_data['Company']=='Pink Cab']
YellowCab = master_data[master_data['Company']=='Yellow Cab']

PinkCab
# Out:
#         Unnamed:_0  Transaction_ID Date_of_Travel   Company           City  \
# 0                0        10000011     2016-01-07  Pink Cab     ATLANTA GA
# 3                3        10000012     2016-01-05  Pink Cab     ATLANTA GA
# 6                6        10395626     2018-10-26  Pink Cab     ATLANTA GA
# 7                7        10000013     2016-01-01  Pink Cab     ATLANTA GA
# 11              11        10000014     2016-01-06  Pink Cab     ATLANTA GA
# ...            ...             ...            ...       ...            ...
# 359332      359332        10200082     2017-07-22  Pink Cab  WASHINGTON DC
# 359346      359346        10262863     2017-11-18  Pink Cab  WASHINGTON DC
# 359356      359356        10417014     2018-12-01  Pink Cab  WASHINGTON DC
# 359358      359358        10197277     2017-07-22  Pink Cab  WASHINGTON DC
# 359363      359363        10267182     2017-11-26  Pink Cab  WASHINGTON DC
#
#         KM_Travelled  Price_Charged  Cost_of_Trip  Customer_ID Payment_Mode  \
# 0           0.644357      -0.191317      0.173709        29290         Card
# 3           0.494768      -0.236620      0.308012        27703         Card
# 6          -0.750173      -0.934524     -0.913051        27703         Card
# 7          -1.105754      -1.086978     -1.193455        28712         Cash
# 11          0.866697      -0.167809      0.414016        28020         Cash
# ...              ...            ...           ...          ...          ...
# 359332     -0.191053      -0.276491     -0.428537        52425         Cash
# 359346     -1.481771      -1.317499     -1.491037        51257         Card
# 359356      1.502655       0.516173      0.935988        51257         Card
# 359358      0.823373      -0.175572      0.523072        51510         Card
# 359363     -0.095414      -0.684031     -0.443374        51510         Card
#
#        Population      Users  Gender  Age  Income_(USD/Month)
# 0        814,885     24,701     Male   28               10813
# 3        814,885     24,701     Male   27                9237
# 6        814,885     24,701     Male   27                9237
# 7        814,885     24,701     Male   53               11242
# 11       814,885     24,701     Male   23               23327
# ...           ...        ...     ...  ...                 ...
# 359332   418,859    127,001     Male   58               10737
# 359346   418,859    127,001     Male   39               15247
# 359356   418,859    127,001     Male   39               15247
# 359358   418,859    127,001   Female   18                6855
# 359363   418,859    127,001   Female   18                6855
#
# [84711 rows x 15 columns]

# %% [markdown]
# # Pink cab company monthly analysis

# %%
plot0 = master_data[master_data.Company=='Pink Cab'].groupby(['Date_of_Travel']).Transaction_ID.count()

plot0
# Out:
# Date_of_Travel
# 2016-01-01     41
# 2016-01-02     52
# 2016-01-03      4
# 2016-01-04      6
# 2016-01-05     23
#              ...
# 2018-12-26     66
# 2018-12-27    217
# 2018-12-28    195
# 2018-12-29     56
# 2018-12-30     58
# Name: Transaction_ID, Length: 1095, dtype: int64

# %% [markdown]
# # Visualize pink cab company montly analysis

# %%
plt.figure(figsize=(30,10))
sns.barplot(x=plot0.index,y=plot0.values)
plt.title('Travel frequency by Month (Pink Cab)',fontsize = 12)
plt.xlabel('Month', fontsize = 12)
plt.ylabel('Values',fontsize = 12)
plt.show()

# %% [markdown]
# # Yellow cab company monthly analysis

# %%
plot1 = master_data[master_data.Company=='Yellow Cab'].groupby(['Date_of_Travel']).Transaction_ID.count()
plot1
# Out:
# Date_of_Travel
# 2016-01-01    140
# 2016-01-02    126
# 2016-01-03     21
# 2016-01-04     41
# 2016-01-05     86
#              ...
# 2018-12-26    252
# 2018-12-27    626
# 2018-12-28    630
# 2018-12-29    201
# 2018-12-30    198
# Name: Transaction_ID, Length: 1095, dtype: int64

# %% [markdown]
# # Visualize yellow cab company montly analysis

# %%
plt.figure(figsize=(34,14))
sns.barplot(x=plot1.index,y=plot1.values)
plt.title('Travel frequency by Month (Pink Cab)',fontsize = 14)
plt.xlabel('Month', fontsize = 14)
plt.ylabel('Values',fontsize = 14)
plt.show()

# %% [markdown]
# # Split km travelled data pink cab yellow cab all data

# %%
overall_distance = master_data['KM_Travelled'].describe()
PinkCab_distance = PinkCab['KM_Travelled'].describe()
YellowCab_distance = YellowCab['KM_Travelled'].describe()

# %% [markdown]
# # Describe overall pinkcab yellow cab data

# %%
df = pd.DataFrame({'Overall': overall_distance.values,
                  'PinkCab': PinkCab_distance.values,
                  'YellowCab': YellowCab_distance.values}, index= ['Count', 'Mean', 'Std. Dev.', 'Min', '25%', '50%', '75%', 'Max'])
df
# Out:
#                 Overall       PinkCab      YellowCab
# Count      3.593920e+05  84711.000000  274681.000000
# Mean       2.936083e-16     -0.000600       0.000185
# Std. Dev.  1.000001e+00      0.999802       1.000064
# Min       -1.689397e+00     -1.689397      -1.689397
# 25%       -8.637958e-01     -0.863796      -0.864613
# 50%       -1.040209e-02     -0.010402      -0.010402
# 75%        8.495311e-01      0.849531       0.849531
# Max        2.078941e+00      2.078941       2.078941

# %%
ax = sns.distplot(PinkCab['KM_Travelled'], kde=False, color='pink', bins=70)
plt.title("Distribution of KM Travelled (Pink Cab)", fontsize=20, y=1.012)
plt.xlabel("KM Travelled", labelpad=15)
plt.ylabel("frequency", labelpad=15)
plt.show()

# %%
ax = sns.distplot(YellowCab['KM_Travelled'], kde=False, color='green',bins=70)
plt.title("Distribution of KM Travelled (Yellow Cab)", fontsize=20, y=1.012)
plt.xlabel("KM Travelled", labelpad=15)
plt.ylabel("frequency", labelpad=15)
# Out:
# Text(0, 0.5, 'frequency')

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(20, 7))
sns.scatterplot(PinkCab['KM_Travelled'], PinkCab['Price_Charged'], ax=ax1)
ax1.set_title('Price vs Distance in Pink Cab', fontsize=20)
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=0, fontsize=15)
sns.scatterplot(YellowCab['KM_Travelled'], YellowCab['Price_Charged'], ax=ax2)
ax2.set_title('Price vs Distance in Yellow Cab', fontsize=20)
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=0, fontsize=15)
plt.show()
