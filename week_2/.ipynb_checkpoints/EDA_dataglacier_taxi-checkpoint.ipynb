# %% [markdown]
# # G2M insight for Cab Investment firm Project

# %%
import pandas as pd

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Reading Data

# %%
cab_data=pd.read_csv("datasets/Cab_Data.csv")
customer_id=pd.read_csv("datasets/Customer_ID.csv")
transaction_id=pd.read_csv("datasets/Transaction_ID.csv")
city=pd.read_csv("datasets/City.csv")

# %% [markdown]
# # Cab data

# %%
cab_data.head()
# Out:
#    Transaction ID  Date of Travel   Company        City  KM Travelled  \
# 0        10000011           42377  Pink Cab  ATLANTA GA         30.45
# 1        10000012           42375  Pink Cab  ATLANTA GA         28.62
# 2        10000013           42371  Pink Cab  ATLANTA GA          9.04
# 3        10000014           42376  Pink Cab  ATLANTA GA         33.17
# 4        10000015           42372  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776

# %% [markdown]
# # Transaction_id head five row

# %%
transaction_id.head()
# Out:
#    Transaction ID  Customer ID Payment_Mode
# 0        10000011        29290         Card
# 1        10000012        27703         Card
# 2        10000013        28712         Cash
# 3        10000014        28020         Cash
# 4        10000015        27182         Card

# %% [markdown]
# # City head five row

# %%
city.head()
# Out:
#              City   Population      Users
# 0     NEW YORK NY   8,405,837    302,149
# 1      CHICAGO IL   1,955,130    164,468
# 2  LOS ANGELES CA   1,595,037    144,132
# 3        MIAMI FL   1,339,155     17,675
# 4  SILICON VALLEY   1,177,609     27,247

# %% [markdown]
# # Customer id head five row

# %%
customer_id.head()
# Out:
#    Customer ID Gender  Age  Income (USD/Month)
# 0        29290   Male   28               10813
# 1        27703   Male   27                9237
# 2        28712   Male   53               11242
# 3        28020   Male   23               23327
# 4        27182   Male   33                8536

# %% [markdown]
# # Check the shape of whole dataset

# %%
print("shape of Cab_Data", cab_data.shape)
print("shape of Customer_ID", customer_id.shape)
print("shape of Transaction_ID", transaction_id.shape)
print("shape of City Data", city.shape)
# Out:
# shape of Cab_Data (359392, 7)
# shape of Customer_ID (49171, 4)
# shape of Transaction_ID (440098, 3)
# shape of City Data (20, 3)

# %% [markdown]
# # check the basic information

# %%
print(cab_data.info())
print("-----------------------")
print(customer_id.info())
print("-----------------------")
print(transaction_id.info())
print("-----------------------")
print(city.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  359392 non-null  int64
#  1   Date of Travel  359392 non-null  int64
#  2   Company         359392 non-null  object
#  3   City            359392 non-null  object
#  4   KM Travelled    359392 non-null  float64
#  5   Price Charged   359392 non-null  float64
#  6   Cost of Trip    359392 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 19.2+ MB
# None
# -----------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49171 entries, 0 to 49170
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         49171 non-null  int64
#  1   Gender              49171 non-null  object
#  2   Age                 49171 non-null  int64
# ...

# %% [markdown]
# # Join cab data and transaction Id based on customer Id

# %%
two_data=cab_data.set_index('Transaction ID').join(transaction_id.set_index('Transaction ID'))

two_data
# Out:
#                 Date of Travel     Company           City  KM Travelled  \
# Transaction ID
# 10000011                 42377    Pink Cab     ATLANTA GA         30.45
# 10000012                 42375    Pink Cab     ATLANTA GA         28.62
# 10000013                 42371    Pink Cab     ATLANTA GA          9.04
# 10000014                 42376    Pink Cab     ATLANTA GA         33.17
# 10000015                 42372    Pink Cab     ATLANTA GA          8.73
# ...                        ...         ...            ...           ...
# 10440101                 43108  Yellow Cab  WASHINGTON DC          4.80
# 10440104                 43104  Yellow Cab  WASHINGTON DC          8.40
# 10440105                 43105  Yellow Cab  WASHINGTON DC         27.75
# 10440106                 43105  Yellow Cab  WASHINGTON DC          8.80
# 10440107                 43102  Yellow Cab  WASHINGTON DC         12.76
#
#                 Price Charged  Cost of Trip  Customer ID Payment_Mode
# Transaction ID
# ...

# %%
two_data.set_index('City').join(city.set_index('City'))
# Out:
#                Date of Travel     Company  KM Travelled  Price Charged  \
# City
# ATLANTA GA              42377    Pink Cab         30.45         370.95
# ATLANTA GA              42375    Pink Cab         28.62         358.52
# ATLANTA GA              42371    Pink Cab          9.04         125.20
# ATLANTA GA              42376    Pink Cab         33.17         377.40
# ATLANTA GA              42372    Pink Cab          8.73         114.62
# ...                       ...         ...           ...            ...
# WASHINGTON DC           43108  Yellow Cab          4.80          69.24
# WASHINGTON DC           43104  Yellow Cab          8.40         113.75
# WASHINGTON DC           43105  Yellow Cab         27.75         437.07
# WASHINGTON DC           43105  Yellow Cab          8.80         146.19
# WASHINGTON DC           43102  Yellow Cab         12.76         191.58
#
#                Cost of Trip  Customer ID Payment_Mode Population      Users
# City
# ...

# %%
master_data=two_data.set_index('Customer ID').join(transaction_id.set_index('Customer ID'),lsuffix='_left', rsuffix='_right')

master_data
# Out:
#              Date of Travel     Company         City  KM Travelled  \
# Customer ID
# 1                     42406  Yellow Cab  NEW YORK NY         42.48
# 1                     42406  Yellow Cab  NEW YORK NY         42.48
# 1                     42406  Yellow Cab  NEW YORK NY         42.48
# 1                     42406  Yellow Cab  NEW YORK NY         42.48
# 1                     42406  Yellow Cab  NEW YORK NY         42.48
# ...                     ...         ...          ...           ...
# 60000                 43465    Pink Cab    BOSTON MA         27.55
# 60000                 43465    Pink Cab    BOSTON MA         27.55
# 60000                 43465    Pink Cab    BOSTON MA         27.55
# 60000                 43465    Pink Cab    BOSTON MA         27.55
# 60000                 43465    Pink Cab    BOSTON MA         27.55
#
#              Price Charged  Cost of Trip Payment_Mode_left  Transaction ID  \
# Customer ID
# ...

# %%
master_data.duplicated()
# Out:
# Customer ID
# 1        False
# 1        False
# 1        False
# 1        False
# 1        False
#          ...
# 60000    False
# 60000    False
# 60000    False
# 60000    False
# 60000    False
# Length: 6721048, dtype: bool

# %%
master_data.isnull()
# Out:
#              Date of Travel  Company   City  KM Travelled  Price Charged  \
# Customer ID
# 1                     False    False  False         False          False
# 1                     False    False  False         False          False
# 1                     False    False  False         False          False
# 1                     False    False  False         False          False
# 1                     False    False  False         False          False
# ...                     ...      ...    ...           ...            ...
# 60000                 False    False  False         False          False
# 60000                 False    False  False         False          False
# 60000                 False    False  False         False          False
# 60000                 False    False  False         False          False
# 60000                 False    False  False         False          False
#
#              Cost of Trip  Payment_Mode_left  Transaction ID  \
# Customer ID
# ...

# %%
master_data
# Out:
#              Date of Travel     Company         City  KM Travelled  \
# Customer ID
# 1                     42406  Yellow Cab  NEW YORK NY         42.48
# 1                     42406  Yellow Cab  NEW YORK NY         42.48
# 1                     42406  Yellow Cab  NEW YORK NY         42.48
# 1                     42406  Yellow Cab  NEW YORK NY         42.48
# 1                     42406  Yellow Cab  NEW YORK NY         42.48
# ...                     ...         ...          ...           ...
# 60000                 43465    Pink Cab    BOSTON MA         27.55
# 60000                 43465    Pink Cab    BOSTON MA         27.55
# 60000                 43465    Pink Cab    BOSTON MA         27.55
# 60000                 43465    Pink Cab    BOSTON MA         27.55
# 60000                 43465    Pink Cab    BOSTON MA         27.55
#
#              Price Charged  Cost of Trip Payment_Mode_left  Transaction ID  \
# Customer ID
# ...

# %% [markdown]
# # Create new data company city and profit

# %%
city_and_profit=merged_df[[4, 5,11]]

city_and_profit
# Out:
#               4           5        11
# 0       Pink Cab  ATLANTA GA  10813.0
# 1       Pink Cab  ATLANTA GA   9237.0
# 2       Pink Cab  ATLANTA GA  11242.0
# 3       Pink Cab  ATLANTA GA  23327.0
# 4       Pink Cab  ATLANTA GA   8536.0
# ...          ...         ...      ...
# 440093       NaN         NaN      NaN
# 440094       NaN         NaN      NaN
# 440095       NaN         NaN      NaN
# 440096       NaN         NaN      NaN
# 440097       NaN         NaN      NaN
#
# [440098 rows x 3 columns]

# %% [markdown]
# # Check new data min max profit

# %%
city_and_profit = city_and_profit.groupby(5).agg(['min', 'max'])

city_and_profit
# Out:
#                       4                   11
#                      min         max     min      max
# 5
# ATLANTA GA      Pink Cab  Yellow Cab  2009.0  34972.0
# AUSTIN TX       Pink Cab  Yellow Cab  2026.0  35000.0
# BOSTON MA       Pink Cab  Yellow Cab  2021.0  34989.0
# CHICAGO IL      Pink Cab  Yellow Cab  2000.0  34996.0
# DALLAS TX       Pink Cab  Yellow Cab  2045.0  34926.0
# DENVER CO       Pink Cab  Yellow Cab  2024.0  34983.0
# LOS ANGELES CA  Pink Cab  Yellow Cab  2001.0  34979.0
# MIAMI FL        Pink Cab  Yellow Cab  2110.0  34640.0
# NASHVILLE TN    Pink Cab  Yellow Cab  2059.0  34769.0
# NEW YORK NY     Pink Cab  Yellow Cab  2003.0  34995.0
# ORANGE COUNTY   Pink Cab  Yellow Cab  2015.0  33608.0
# PHOENIX AZ      Pink Cab  Yellow Cab  2057.0  34818.0
# PITTSBURGH PA   Pink Cab  Yellow Cab  2069.0  34660.0
# SACRAMENTO CA   Pink Cab  Yellow Cab  2140.0  34492.0
# SAN DIEGO CA    Pink Cab  Yellow Cab  2029.0  34972.0
# ...

# %% [markdown]
# # Remove NaN values in city and profit data

# %%
city_and_profit=city_and_profit.dropna()

city_and_profit
# Out:
#                       4                   11
#                      min         max     min      max
# 5
# ATLANTA GA      Pink Cab  Yellow Cab  2009.0  34972.0
# AUSTIN TX       Pink Cab  Yellow Cab  2026.0  35000.0
# BOSTON MA       Pink Cab  Yellow Cab  2021.0  34989.0
# CHICAGO IL      Pink Cab  Yellow Cab  2000.0  34996.0
# DALLAS TX       Pink Cab  Yellow Cab  2045.0  34926.0
# DENVER CO       Pink Cab  Yellow Cab  2024.0  34983.0
# LOS ANGELES CA  Pink Cab  Yellow Cab  2001.0  34979.0
# MIAMI FL        Pink Cab  Yellow Cab  2110.0  34640.0
# NASHVILLE TN    Pink Cab  Yellow Cab  2059.0  34769.0
# NEW YORK NY     Pink Cab  Yellow Cab  2003.0  34995.0
# ORANGE COUNTY   Pink Cab  Yellow Cab  2015.0  33608.0
# PHOENIX AZ      Pink Cab  Yellow Cab  2057.0  34818.0
# PITTSBURGH PA   Pink Cab  Yellow Cab  2069.0  34660.0
# SACRAMENTO CA   Pink Cab  Yellow Cab  2140.0  34492.0
# SAN DIEGO CA    Pink Cab  Yellow Cab  2029.0  34972.0
# ...

# %% [markdown]
# # Visualize city and profit data in bar plotting

# %%
city_and_profit[11].plot.bar(figsize=(10, 10),subplots=True)
# Out:
# array([<AxesSubplot:title={'center':'min'}, xlabel='5'>,
#        <AxesSubplot:title={'center':'max'}, xlabel='5'>], dtype=object)
